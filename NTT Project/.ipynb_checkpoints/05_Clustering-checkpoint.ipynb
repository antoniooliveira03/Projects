# %% [markdown]
# # <center>Dunnhumby - The Complete Journey<center>
#
# ** **
#
# # <center>*05 - Clustering*<center>
#
#
# In this notebook several Clustering Algorithms will be implemented.
#
#
# <br>
#
# This project was developed by <br><br>
#
# *<center>António Oliveira | NTT Data Summer Internship 2024<center>*

# %% [markdown]
# ** **
#
# <a class="anchor" id="0"></a>
#
# # Table of Contents
#
# 1. [Importing Libraries & Data](#1.-Importing-Libraries-&-Data)
#
#     1.1 [Libraries](#1.1-Libraries)
#
#     1.2 [Data](#1.2-Data) <br><br>
#
# 2. [K-Means](#2.-K-Means) <br><br>
#
# 3. [Hierarchical Clustering](#3.-Hierarchical-Clustering) <br><br>
#
# 4. [DB Scan](#4.-DB-Scan) <br><br>
#
# 5. [UMAP](#5.-UMAP) <br>
#
#     5.1 [UMAP into DB Scan](#5.1-UMAP-into-DB-Scan) <br><br>
#
# 6. [Export](#6.-Export)

# %% [markdown]
# ## 1. Import Libraries & Data

# %% [markdown]
# ### 1.1 Libraries

# %%
import pandas as pd
import numpy as np


# scalers
from sklearn.preprocessing import StandardScaler


# cluster
from sklearn.cluster import DBSCAN, MeanShift, KMeans, AgglomerativeClustering, estimate_bandwidth

from sklearn.metrics import confusion_matrix

# UMAP
#!pip install umap-learn
import umap


import matplotlib.pyplot as plt

import functions

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1.2 Data

# %%
path = '/Users/antoniooliveira/Downloads/NTT project/Clustering'
#path = "C:/Users/aprataso/Downloads/final_data/Clustering"

customer_info = pd.read_csv(f'{path}/customer_info_treated.csv')
customer_info = customer_info.set_index('household_key')
customer_info.head(2)
# Out:
#                retail_disc  coupon_disc  coupon_match_disc  \
# household_key
# 1                   -0.404       -0.047             -0.015
# 2                   -0.469       -0.013              0.000
#
#               first_transaction_date  marital_status_code  homeowner_desc  \
# household_key
# 1                         2021-02-20                    0       Homeowner
# 2                         2021-04-13                    1  Probable Owner
#
#               marital_status    age_group  adult_category_size  has_kids  \
# household_key
# 1                    married       senior                2.000     0.000
# 2                     single  young adult                1.000     0.000
#
#                avg_age  avg_income  n_kids  n_household  Groceries_spend  \
# household_key
# 1               65.000   42000.000   0.000        2.000         3285.020
# 2               21.500   25000.000   0.000        1.000         1361.500
#
#                Delicacies_spend  Meat_spend  Bakery_spend  DRUG GM_spend  \
# household_key
# 1                       226.990     373.560       102.010        568.230
# 2                        50.010     238.860        26.550        353.110
#
#                SALAD BAR_spend  MISC SALES TRAN_spend  RESTAURANT_spend  \
# household_key
# 1                       44.090                 21.400             4.470
# 2                        0.000                  4.560             0.000
#
#                FLORAL_spend  Seafood_spend  COSMETICS_spend  KIOSK-GAS_spend  \
# household_key
# 1                     8.550          0.000            0.000            0.000
# 2                    23.530          9.620           23.620            0.000
#
#                CHEF SHOPPE_spend  GARDEN CENTER_spend  MISC. TRANS._spend  \
# household_key
# 1                          0.000                0.000               0.000
# 2                          0.000                0.000               0.000
#
#                SPIRITS_spend  AUTOMOTIVE_spend  TRAVEL & LEISUR_spend  \
# household_key
# 1                      0.000             0.000                  0.000
# 2                      0.000             0.000                  0.000
#
#                CNTRL/STORE SUP_spend  COUP/STR & MFG_spend  \
# household_key
# 1                              0.000                 0.000
# 2                              0.000                 0.000
#
#                GM MERCH EXP_spend  POSTAL CENTER_spend  DELI/SNACK BAR_spend  \
# household_key
# 1                           0.000                0.000                 0.000
# 2                           0.000                0.000                 0.000
#
#                Photo/Video_spend  CHARITABLE CONT_spend  RX_spend  \
# household_key
# 1                          0.000                  0.000     0.000
# 2                          0.000                  0.000     0.000
#
#                VIDEO RENTAL_spend  PROD-WHS SALES_spend  \
# household_key
# 1                           0.000                 0.000
# 2                           0.000                 0.000
#
#                PHARMACY SUPPLY_spend  TOYS_spend  HBC_spend  \
# household_key
# 1                              0.000       0.000      0.000
# 2                              0.000       0.000      0.000
#
#                ELECT &PLUMBING_spend  HOUSEWARES_spend  gender  \
# household_key
# 1                              0.000             0.000   2.000
# 2                              0.000             0.000   0.000
#
#                homeowner_code  total_quantity  total_sales_value  \
# household_key
# 1                           0            1997           4634.320
# 2                           1             834           2091.360
#
#                unique_dep_count
# household_key
# 1                            10
# 2                             9

# %%
pd.set_option('display.float_format', '{:.3f}'.format)
customer_info.describe().T
# Out:
#                          count       mean        std       min       25%  \
# retail_disc           2500.000     -0.560      0.278    -4.752    -0.637
# coupon_disc           2500.000     -0.014      0.027    -0.421    -0.015
# coupon_match_disc     2500.000     -0.002      0.006    -0.101    -0.002
# marital_status_code   2500.000      0.989      0.852     0.000     0.000
# adult_category_size   2500.000      1.447      0.497     1.000     1.000
# has_kids              2500.000      0.338      0.473     0.000     0.000
# avg_age               2500.000     39.913     14.452    21.500    29.500
# avg_income            2500.000  78072.000  66852.827 15000.000 29500.000
# n_kids                2500.000      0.443      0.706     0.000     0.000
# n_household           2500.000      1.954      1.048     1.000     1.000
# Groceries_spend       2500.000   2033.183   2063.025     1.860   616.980
# Delicacies_spend      2500.000    111.688    172.715     0.000    13.088
# Meat_spend            2500.000    411.464    456.970     0.000    92.433
# Bakery_spend          2500.000     52.115     71.598     0.000     8.852
# DRUG GM_spend         2500.000    451.721    600.312     0.000    96.268
# SALAD BAR_spend       2500.000     13.248     38.201     0.000     0.000
# MISC SALES TRAN_spend 2500.000     51.343    332.715     0.000     0.000
# RESTAURANT_spend      2500.000      0.851      6.845     0.000     0.000
# FLORAL_spend          2500.000     16.973     41.783     0.000     0.000
# Seafood_spend         2500.000     39.632     83.126     0.000     0.000
# COSMETICS_spend       2500.000     13.850     33.447     0.000     0.000
# KIOSK-GAS_spend       2500.000    232.928    532.531     0.000     0.000
# CHEF SHOPPE_spend     2500.000      0.981      3.752     0.000     0.000
# GARDEN CENTER_spend   2500.000      3.282     23.500     0.000     0.000
# MISC. TRANS._spend    2500.000      4.571     35.974     0.000     0.000
# SPIRITS_spend         2500.000      9.275     68.039     0.000     0.000
# AUTOMOTIVE_spend      2500.000      0.194      1.665     0.000     0.000
# TRAVEL & LEISUR_spend 2500.000      1.092      3.618     0.000     0.000
# CNTRL/STORE SUP_spend 2500.000      0.021      0.495     0.000     0.000
# COUP/STR & MFG_spend  2500.000      0.440      2.425     0.000     0.000
# GM MERCH EXP_spend    2500.000      0.043      0.514     0.000     0.000
# POSTAL CENTER_spend   2500.000      0.010      0.222     0.000     0.000
# DELI/SNACK BAR_spend  2500.000      0.015      0.328     0.000     0.000
# Photo/Video_spend     2500.000      0.033      0.494     0.000     0.000
# CHARITABLE CONT_spend 2500.000      0.003      0.146     0.000     0.000
# RX_spend              2500.000      0.068      1.050     0.000     0.000
# VIDEO RENTAL_spend    2500.000      0.009      0.280     0.000     0.000
# PROD-WHS SALES_spend  2500.000      0.003      0.120     0.000     0.000
# PHARMACY SUPPLY_spend 2500.000      0.007      0.192     0.000     0.000
# TOYS_spend            2500.000      0.004      0.143     0.000     0.000
# HBC_spend             2500.000      0.004      0.102     0.000     0.000
# ELECT &PLUMBING_spend 2500.000      0.000      0.021     0.000     0.000
# HOUSEWARES_spend      2500.000      0.001      0.064     0.000     0.000
# gender                2500.000      1.135      0.804     0.000     0.000
# homeowner_code        2500.000      1.445      1.502     0.000     0.000
# total_quantity        2500.000 104274.249 244456.076     5.000   770.000
# total_sales_value     2500.000   3449.055   3583.873     8.740  1038.827
# unique_dep_count      2500.000     10.005      3.224     1.000     8.000
#
#                             50%        75%         max
# retail_disc              -0.504     -0.413      -0.036
# coupon_disc              -0.005      0.000       0.000
# coupon_match_disc        -0.000      0.000       0.000
# marital_status_code       1.000      2.000       2.000
# adult_category_size       1.000      2.000       2.000
# has_kids                  0.000      1.000       1.000
# avg_age                  39.500     49.500      65.000
# avg_income            62000.000 112000.000  250000.000
# n_kids                    0.000      1.000       3.000
# n_household               2.000      3.000       5.000
# Groceries_spend        1377.490   2816.665   16223.980
# Delicacies_spend         49.230    133.697    1935.010
# Meat_spend              261.750    547.687    3736.710
# Bakery_spend             27.795     69.075     916.070
# DRUG GM_spend           240.665    570.535    5934.370
# SALAD BAR_spend           0.000     10.325     675.230
# MISC SALES TRAN_spend     2.130     16.340   11942.400
# RESTAURANT_spend          0.000      0.000     178.190
# FLORAL_spend              0.000     18.260     938.560
# Seafood_spend            12.820     41.940    1821.180
# COSMETICS_spend           1.060     12.197     566.110
# KIOSK-GAS_spend          21.400    192.893    8184.660
# CHEF SHOPPE_spend         0.000      0.000      80.000
# GARDEN CENTER_spend       0.000      0.000    1002.260
# MISC. TRANS._spend        0.000      2.450    1067.880
# SPIRITS_spend             0.000      0.000    2827.090
# AUTOMOTIVE_spend          0.000      0.000      36.020
# TRAVEL & LEISUR_spend     0.000      0.000      68.770
# CNTRL/STORE SUP_spend     0.000      0.000      21.400
# COUP/STR & MFG_spend      0.000      0.000      50.450
# GM MERCH EXP_spend        0.000      0.000      12.890
# POSTAL CENTER_spend       0.000      0.000       9.580
# DELI/SNACK BAR_spend      0.000      0.000      13.580
# Photo/Video_spend         0.000      0.000      14.970
# CHARITABLE CONT_spend     0.000      0.000       7.210
# RX_spend                  0.000      0.000      22.350
# VIDEO RENTAL_spend        0.000      0.000      11.220
# PROD-WHS SALES_spend      0.000      0.000       5.350
# PHARMACY SUPPLY_spend     0.000      0.000       6.390
# TOYS_spend                0.000      0.000       6.810
# HBC_spend                 0.000      0.000       2.880
# ELECT &PLUMBING_spend     0.000      0.000       1.070
# HOUSEWARES_spend          0.000      0.000       3.200
# gender                    1.000      2.000       2.000
# homeowner_code            1.000      2.000       4.000
# total_quantity        11084.500  87640.000 4479917.000
# total_sales_value      2309.105   4722.680   41004.030
# unique_dep_count         10.000     12.000      19.000

# %% [markdown]
# Since our data is very sparse, Spend columns with maximum values bellow 10 will be dropped

# %%
customer_info = customer_info.drop(['HOUSEWARES_spend', 'ELECT &PLUMBING_spend', 'HBC_spend', 'TOYS_spend',
                                    'PHARMACY SUPPLY_spend', 'PROD-WHS SALES_spend', 'CHARITABLE CONT_spend',
                                    'POSTAL CENTER_spend', 'coupon_disc', 'coupon_match_disc'], axis = 1)

# %% [markdown]
# Creating a Dataframe that only contains numerical columns

# %%
info_numeric = customer_info.loc[:, ~customer_info.columns.isin(
    ['homeowner_desc', 'marital_status', 'age_group',
     'first_transaction_date'])]

# %% [markdown]
# Verifying if *info_numeric* only contains numeric data types

# %%
info_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2500 entries, 1 to 2500
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   retail_disc            2500 non-null   float64
#  1   marital_status_code    2500 non-null   int64
#  2   adult_category_size    2500 non-null   float64
#  3   has_kids               2500 non-null   float64
#  4   avg_age                2500 non-null   float64
#  5   avg_income             2500 non-null   float64
#  6   n_kids                 2500 non-null   float64
#  7   n_household            2500 non-null   float64
#  8   Groceries_spend        2500 non-null   float64
#  9   Delicacies_spend       2500 non-null   float64
#  10  Meat_spend             2500 non-null   float64
#  11  Bakery_spend           2500 non-null   float64
#  12  DRUG GM_spend          2500 non-null   float64
#  13  SALAD BAR_spend        2500 non-null   float64
#  14  MISC SALES TRAN_spend  2500 non-null   float64
#  15  RESTAURANT_spend       2500 non-null   float64
#  16  FLORAL_spend           2500 non-null   float64
#  17  Seafood_spend          2500 non-null   float64
#  18  COSMETICS_spend        2500 non-null   float64
#  19  KIOSK-GAS_spend        2500 non-null   float64
#  20  CHEF SHOPPE_spend      2500 non-null   float64
#  21  GARDEN CENTER_spend    2500 non-null   float64
#  22  MISC. TRANS._spend     2500 non-null   float64
#  23  SPIRITS_spend          2500 non-null   float64
#  24  AUTOMOTIVE_spend       2500 non-null   float64
#  25  TRAVEL & LEISUR_spend  2500 non-null   float64
#  26  CNTRL/STORE SUP_spend  2500 non-null   float64
#  27  COUP/STR & MFG_spend   2500 non-null   float64
#  28  GM MERCH EXP_spend     2500 non-null   float64
#  29  DELI/SNACK BAR_spend   2500 non-null   float64
#  30  Photo/Video_spend      2500 non-null   float64
#  31  RX_spend               2500 non-null   float64
#  32  VIDEO RENTAL_spend     2500 non-null   float64
#  33  gender                 2500 non-null   float64
#  34  homeowner_code         2500 non-null   int64
#  35  total_quantity         2500 non-null   int64
#  36  total_sales_value      2500 non-null   float64
#  37  unique_dep_count       2500 non-null   int64
# dtypes: float64(34), int64(4)
# memory usage: 761.7 KB

# %% [markdown]
# Since the ranges of each column are very different, it is necessary to scale the data

# %%
scaled_info = StandardScaler().fit_transform(info_numeric)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1814: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   return lib.map_infer(values, mapper, convert=convert)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## 2. K-Means
#
# <a class='anchor' id='1'></a>
# [Top &#129033;](#0)

# %%
dispersion = []
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(scaled_info)
    dispersion.append(kmeans.inertia_)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# **Elbow Method**

# %%
plt.plot(range(1, 20), dispersion, marker='o', color='orange')
plt.xlabel('Number of clusters')
plt.ylabel('Dispersion (inertia)')
plt.xticks(np.arange(0, 21, step=2))  
#plt.vlines(7, 5000, 600000, color='red')

plt.show()

# %% [markdown]
# Applying **K-Means** with N clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=42).fit(scaled_info)

info_numeric['cluster_kmeans'] = kmeans.predict(scaled_info)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/mm/fxsq_1490x9dd2w76tqvt3kr0000gn/T/ipykernel_25511/4290672463.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_numeric['cluster_kmeans'] = kmeans.predict(scaled_info)

# %%
info_numeric.groupby(['cluster_kmeans']).size().plot(kind='bar', color='orange')
plt.show()

# %%
pd.set_option('display.float_format', '{:.3f}'.format)

info_numeric.groupby(['cluster_kmeans']).mean().T

#   'A': 0, married
#   'B': 1, single
#   'U': 2 unknown
#     'Single Male': 0,
#     'Single Female': 1,
#     '2 Adults No Kids': 2,
#     '2 Adults Kids': 2

# 0 - couples w/ kids
# 1 - single females
# 2 - elderly, high income
# 3 - young singles w/o kids
# 4 - high spend on GAS
# Out:
# cluster_kmeans                 0          1         2           3          4
# retail_disc               -0.590     -0.537    -0.552      -0.485     -0.525
# marital_status_code        0.387      1.270     1.351       2.000      0.752
# adult_category_size        1.967      1.374     1.045       2.000      1.710
# has_kids                   0.708      0.117     0.150       0.000      0.393
# avg_age                   42.064     42.488    36.645      65.000     42.859
# avg_income            102419.036  64713.701 62278.883  187000.000 101548.276
# n_kids                     0.967      0.135     0.151       0.000      0.690
# n_household                2.951      1.703     1.233       2.000      2.483
# Groceries_spend         1399.497   3750.928  1003.932   15067.610   7181.661
# Delicacies_spend          70.959    201.761    47.152    1935.010    492.583
# Meat_spend               298.566    784.117   208.156    2058.250   1253.906
# Bakery_spend              37.525     88.596    26.215     390.920    196.774
# DRUG GM_spend            289.321    814.732   214.520    5934.370   1823.245
# SALAD BAR_spend            8.734     19.808     7.532      71.440     57.533
# MISC SALES TRAN_spend     25.064     75.353    12.073   11942.400    320.979
# RESTAURANT_spend           0.388      0.886     0.163      47.540      7.994
# FLORAL_spend              11.011     24.504     7.427     938.560     88.001
# Seafood_spend             23.277     71.677    19.061     363.810    170.388
# COSMETICS_spend            7.823     26.393     4.713     226.960     70.257
# KIOSK-GAS_spend          114.982    437.296    72.343     934.450   1366.437
# CHEF SHOPPE_spend          0.488      1.702     0.311       4.260      6.155
# GARDEN CENTER_spend        1.675      3.941     0.911    1002.260     20.403
# MISC. TRANS._spend         2.298      7.051     2.178      30.030     26.150
# SPIRITS_spend              4.356     13.080     5.894      53.480     48.215
# AUTOMOTIVE_spend           0.226      0.295     0.070       0.000      0.577
# TRAVEL & LEISUR_spend      0.707      2.299     0.409       2.680      4.130
# CNTRL/STORE SUP_spend      0.011      0.018     0.003       0.000      0.221
# COUP/STR & MFG_spend       0.206      0.653     0.191       0.000      2.848
# GM MERCH EXP_spend         0.029      0.134     0.008       0.000      0.072
# DELI/SNACK BAR_spend       0.000      0.059     0.006       0.000      0.022
# Photo/Video_spend          0.003      0.100     0.013       0.000      0.114
# RX_spend                   0.054      0.083     0.030       0.000      0.382
# VIDEO RENTAL_spend         0.014      0.000     0.011       0.000      0.000
# gender                     1.831      1.112     0.550       2.000      1.586
# homeowner_code             0.640      1.609     2.095       2.000      0.648
# total_quantity         50014.204 187241.761 30049.189 4479917.000 637593.441
# total_sales_value       2297.229   6325.550  1633.338   41004.030  13139.148
# unique_dep_count           9.320     12.967     8.434      19.000     15.221

# %% [markdown]
# ## 3. Hierarchical Clustering
#
# <a class='anchor' id='1'></a>
# [Top &#129033;](#0)

# %% [markdown]
# Using Agglomerative Hierarchical Clustering with *Ward* Linkage

# %%
agg_clust = AgglomerativeClustering(
    linkage='ward', distance_threshold=0, n_clusters=None
    ).fit(scaled_info)

# %% [markdown]
# **Dendrogram**

# %%
fig, ax = plt.subplots()
plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
functions.plot_dendrogram(agg_clust, truncate_mode="level", p=50)
plt.axhline(y = 200, color = 'r', linestyle = '-')

plt.show()

# %%
info_numeric['cluster_ward'] = AgglomerativeClustering(
    linkage='ward', n_clusters=4
    ).fit_predict(scaled_info)
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_8536\2294577397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_numeric['cluster_ward'] = AgglomerativeClustering(

# %%
info_numeric.groupby(['cluster_ward']).size().plot(kind='bar', color='orange')
plt.show()

# %%
info_numeric.groupby(['cluster_ward']).mean().T
# Out:
# cluster_ward                  0          1          2           3
# household_key          1222.333   1282.469   1298.655    1023.000
# retail_disc              -0.559     -0.521     -0.568      -0.485
# coupon_disc              -0.014     -0.021     -0.012      -0.018
# coupon_match_disc        -0.002     -0.004     -0.002      -0.002
# marital_status_code       1.287      0.917      0.433       2.000
# adult_category_size       1.147      1.593      1.990       2.000
# has_kids                  0.176      0.276      0.657       0.000
# avg_age                  38.950     42.597     41.234      65.000
# avg_income            64218.406  95989.655 101091.862  187000.000
# n_kids                    0.202      0.448      0.900       0.000
# n_household               1.437      2.179      2.895       2.000
# Groceries_spend        1885.816   6423.108   1512.608   15067.610
# DELI_spend               96.783    446.032     77.921    1935.010
# Meat_spend              393.945   1127.590    314.728    2058.250
# Bakery_spend             45.862    173.651     41.865     390.920
# DRUG GM_spend           410.192   1614.179    316.136    5934.370
# SALAD BAR_spend          12.523     49.560      8.063      71.440
# MISC SALES TRAN_spend    36.030    311.435     19.314   11942.400
# RESTAURANT_spend          0.340      7.704      0.540      47.540
# FLORAL_spend             13.753     75.752     11.452     938.560
# Seafood_spend            37.749    144.198     24.118     363.810
# COSMETICS_spend          11.576     60.397      9.594     226.960
# KIOSK-GAS_spend         180.898   1246.764    149.789     934.450
# CHEF SHOPPE_spend         0.872      4.714      0.518       4.260
# GARDEN CENTER_spend       1.907     17.068      2.201    1002.260
# MISC. TRANS._spend        2.527     41.863      1.762      30.030
# SPIRITS_spend             8.868     41.641      4.209      53.480
# DAIRY DELI_spend          0.045      0.037      0.005       0.000
# AUTOMOTIVE_spend          0.269      0.304      0.031       0.000
# TRAVEL & LEISUR_spend     0.913      5.582      0.627       2.680
# CNTRL/STORE SUP_spend     0.010      0.221      0.005       0.000
# COUP/STR & MFG_spend      0.269      3.640      0.194       0.000
# GM MERCH EXP_spend        0.065      0.014      0.008       0.000
# POSTAL CENTER_spend       0.015      0.011      0.001       0.000
# DELI/SNACK BAR_spend      0.001      0.126      0.024       0.000
# VIDEO_spend               0.000      0.257      0.000       0.000
# CHARITABLE CONT_spend     0.001      0.000      0.009       0.000
# RX_spend                  0.103      0.074      0.002       0.000
# VIDEO RENTAL_spend        0.015      0.000      0.000       0.000
# PHOTO_spend               0.027      0.018      0.000       0.000
# PROD-WHS SALES_spend      0.000      0.056      0.000       0.000
# PHARMACY SUPPLY_spend     0.012      0.000      0.000       0.000
# TOYS_spend                0.007      0.000      0.000       0.000
# HBC_spend                 0.007      0.000      0.000       0.000
# ELECT &PLUMBING_spend     0.001      0.000      0.000       0.000
# HOUSEWARES_spend          0.002      0.000      0.000       0.000
# gender                    0.751      1.428      1.813       2.000
# total_quantity        78612.180 585102.814  61735.147 4479917.000
# total_sales_value      3141.401  11795.996   2495.724   41004.030
# cluster_kmeans            0.923      1.786      0.096       3.000

# %% [markdown]
# ## 4. DB Scan
#
# <a class='anchor' id='1'></a>
# [Top &#129033;](#0)

# %%
info_numeric['cluster_dbscan'] = DBSCAN(eps=10, min_samples = 40).fit_predict(scaled_info)
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_8536\2362419876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_numeric['cluster_dbscan'] = DBSCAN(eps=10, min_samples = 40).fit_predict(scaled_info)

# %%
info_numeric.groupby(['cluster_dbscan']).size().plot(kind='bar', color='orange')
plt.show()

# %%
info_numeric.groupby(['cluster_dbscan']).mean().T
# Out:
# cluster_dbscan                -1         0
# household_key           1391.316  1245.905
# retail_disc               -0.551    -0.560
# coupon_disc               -0.030    -0.013
# coupon_match_disc         -0.004    -0.002
# marital_status_code        0.924     0.991
# adult_category_size        1.570     1.443
# has_kids                   0.342     0.338
# avg_age                   39.804    39.917
# avg_income             91126.582 77646.014
# n_kids                     0.595     0.438
# n_household                2.203     1.945
# Groceries_spend         5729.711  1912.561
# DELI_spend               402.894   102.153
# Meat_spend              1012.513   391.851
# Bakery_spend             157.043    48.691
# DRUG GM_spend           1791.472   408.003
# SALAD BAR_spend           69.581    11.410
# MISC SALES TRAN_spend    428.949    39.022
# RESTAURANT_spend           9.677     0.563
# FLORAL_spend              75.037    15.078
# Seafood_spend            168.571    35.424
# COSMETICS_spend           61.802    12.286
# KIOSK-GAS_spend          758.709   215.771
# CHEF SHOPPE_spend          6.622     0.797
# GARDEN CENTER_spend       30.182     2.404
# MISC. TRANS._spend        40.021     3.415
# SPIRITS_spend             70.792     7.268
# DAIRY DELI_spend           0.205     0.026
# AUTOMOTIVE_spend           1.272     0.159
# TRAVEL & LEISUR_spend      5.178     0.959
# CNTRL/STORE SUP_spend      0.419     0.008
# COUP/STR & MFG_spend       3.661     0.335
# GM MERCH EXP_spend         0.512     0.028
# POSTAL CENTER_spend        0.182     0.005
# DELI/SNACK BAR_spend       0.266     0.007
# VIDEO_spend                0.471     0.000
# CHARITABLE CONT_spend      0.091     0.000
# RX_spend                   1.267     0.029
# VIDEO RENTAL_spend         0.291     0.000
# PHOTO_spend                0.168     0.013
# PROD-WHS SALES_spend       0.102     0.000
# PHARMACY SUPPLY_spend      0.229     0.000
# TOYS_spend                 0.086     0.002
# HBC_spend                  0.128     0.000
# ELECT &PLUMBING_spend      0.014     0.000
# HOUSEWARES_spend           0.041     0.000
# gender                     1.405     1.126
# total_quantity        435141.316 93477.678
# total_sales_value      10828.158  3208.266
# cluster_kmeans             1.633     0.675
# cluster_ward               0.658     0.710

# %% [markdown]
# ## 5. UMAP
#
# <a class='anchor' id='1'></a>
# [Top &#129033;](#0)

# %%
umap_object = umap.UMAP(n_neighbors=20, min_dist=0.1, n_components=2, random_state=42)

# n_neighbours - neighbours to consider; lower values --> more local structure
# min_dist - min_dist between neighbours; low values --> tighter groups
# n_components - dimensions of the output

# %%
X_sample = info_numeric.sort_index()

# %%
umap_embedding = umap_object.fit_transform(X_sample)
# Out:
# /Users/antoniooliveira/anaconda3/envs/Text_Mining/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/antoniooliveira/anaconda3/envs/Text_Mining/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/antoniooliveira/anaconda3/envs/Text_Mining/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/antoniooliveira/anaconda3/envs/Text_Mining/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
plt.scatter(umap_embedding[:, 0], umap_embedding[:, 1],s=0.5)

# %% [markdown]
# ### 5.1 UMAP into DB Scan

# %%
clusterable_embedding = umap.UMAP(n_neighbors=50, min_dist=0.1, 
                                  n_components=2, random_state=42).fit_transform(X_sample)
# Out:
# c:\Users\aprataso\AppData\Local\anaconda3\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
plt.scatter(clusterable_embedding[:, 0], clusterable_embedding[:, 1],s=0.5)

# %%
labels = DBSCAN(eps=2, min_samples=20).fit_predict(clusterable_embedding)

# %%
info_numeric['cluster_umap_dbscan'] = labels
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_3644\242391019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_numeric['cluster_umap_dbscan'] = labels

# %%
clustered = (labels >= 0) 
# Plotting points not belonging to any cluster in gray (outliers)
plt.scatter(clusterable_embedding[~clustered, 0],
            clusterable_embedding[~clustered, 1],
            color=(0.5, 0.5, 0.5),
            s=0.3,
            alpha=0.5)

# Plotting points belonging to each cluster
plt.scatter(clusterable_embedding[clustered, 0],
            clusterable_embedding[clustered, 1],
            c=labels[clustered],
            s=0.5,
            cmap='Spectral');

# %%
info_numeric.groupby(['cluster_umap_dbscan']).size().plot(kind='bar', color='orange')
plt.show()

# %%
info_numeric.groupby(['cluster_umap_dbscan']).mean().T

#0
#1 - pobres
#2 - w/ kids
#5 - love groceries, mt quantidade
#9 - 
#10 - ricos
# Out:
# cluster_umap_dbscan          0         1          2         3          4   \
# household_key          1316.892  1722.794    884.737   936.703   1223.025
# retail_disc              -0.501    -0.549     -0.525    -0.556     -0.615
# marital_status_code       1.108     0.927      0.863     1.174      0.823
# adult_category_size       1.441     1.353      1.562     1.215      1.468
# has_kids                  0.206     0.367      0.512     0.213      0.544
# avg_age                  49.054    31.757     43.569    31.139     46.310
# avg_income            42000.000 29004.587 137000.000 16459.128 162000.000
# n_kids                    0.314     0.367      0.750     0.262      0.595
# n_household               1.882     1.766      2.312     1.534      2.063
# Groceries_spend        1743.400  1177.860   1377.358  1295.408   1235.678
# Delicacies_spend         94.475    60.335     64.658    69.548     83.044
# Meat_spend              354.795   285.830    326.303   304.303    244.805
# Bakery_spend             39.250    27.171     39.776    38.749     34.295
# DRUG GM_spend           318.301   280.518    287.374   270.002    244.298
# SALAD BAR_spend           8.816     6.597      5.306    12.547      7.313
# MISC SALES TRAN_spend     5.095     6.160      8.973     9.078      5.626
# RESTAURANT_spend          0.198     0.280      0.435     0.317      1.484
# FLORAL_spend              8.921     7.256     10.385     7.071     13.770
# Seafood_spend            30.251    26.620     20.101    23.722     25.068
# COSMETICS_spend          10.168     9.139      8.191     7.305      7.844
# KIOSK-GAS_spend           0.636     0.167      9.772    16.354      6.683
# CHEF SHOPPE_spend         1.137     0.389      0.428     0.722      0.487
# GARDEN CENTER_spend       1.495     0.886      2.588     1.411      0.428
# MISC. TRANS._spend        1.637     3.933      1.352     4.128      2.661
# SPIRITS_spend             5.407     3.969      4.832     4.187      3.009
# AUTOMOTIVE_spend          0.009     0.212      0.200     0.048      0.318
# TRAVEL & LEISUR_spend     0.815     0.919      0.937     0.658      0.740
# CNTRL/STORE SUP_spend     0.000     0.015      0.000     0.006      0.000
# COUP/STR & MFG_spend      0.250     0.475      0.143     0.194      0.542
# GM MERCH EXP_spend        0.000     0.000      0.025     0.031      0.161
# DELI/SNACK BAR_spend      0.035     0.000      0.000     0.000      0.015
# Photo/Video_spend         0.000     0.024      0.060     0.060      0.000
# RX_spend                  0.000     0.059      0.000     0.017      0.000
# VIDEO RENTAL_spend        0.000     0.000      0.000     0.017      0.000
# gender                    1.049     1.000      1.288     0.913      1.241
# homeowner_code            1.716     1.541      1.587     1.978      1.316
# total_quantity         1383.431   841.427   4829.900  7647.384   3396.051
# total_sales_value      2625.091  1898.821   2169.196  2065.909   1918.361
# unique_dep_count          8.569     7.904      8.588     8.834      8.392
# cluster_kmeans            1.667     1.899      1.413     2.311      1.658
#
# cluster_umap_dbscan           5         6         7          8          9   \
# household_key           1318.758  1135.286  1304.112    890.291   1482.012
# retail_disc               -0.563    -0.537    -0.586     -0.585     -0.556
# marital_status_code        0.944     1.214     0.824      0.961      1.110
# adult_category_size        1.515     1.429     1.524      1.350      1.524
# has_kids                   0.328     0.305     0.433      0.456      0.354
# avg_age                   40.168    44.062    38.246     51.617     55.799
# avg_income             84147.032 62000.000 87000.000 112000.000 188853.659
# n_kids                     0.455     0.429     0.561      0.612      0.427
# n_household                2.055     1.961     2.118      1.971      1.963
# Groceries_spend         2814.394  2342.037  1520.395   1261.918   1288.138
# Delicacies_spend         155.522   130.353    82.791     68.233     79.120
# Meat_spend               545.962   427.502   332.122    246.355    220.815
# Bakery_spend              70.608    61.694    36.787     29.084     39.272
# DRUG GM_spend            628.546   589.396   349.523    302.513    260.760
# SALAD BAR_spend           17.228    17.363    10.180      9.277      8.770
# MISC SALES TRAN_spend    108.590    11.678     9.011      7.342      6.036
# RESTAURANT_spend           1.403     0.883     0.488      0.103      0.153
# FLORAL_spend              25.091    18.560    15.197     10.723     15.599
# Seafood_spend             54.621    43.374    41.481     22.022     20.768
# COSMETICS_spend           19.703    14.603     9.029     12.745      9.256
# KIOSK-GAS_spend          522.211    32.253    23.149      8.961     21.288
# CHEF SHOPPE_spend          1.308     1.766     0.660      0.493      0.469
# GARDEN CENTER_spend        5.233     3.371     2.196      1.157      3.983
# MISC. TRANS._spend         6.749     2.792     1.427      1.996      4.376
# SPIRITS_spend             11.769    30.787     4.199      7.067      6.307
# AUTOMOTIVE_spend           0.241     0.215     0.301      0.239      0.000
# TRAVEL & LEISUR_spend      1.237     1.455     0.915      1.700      1.604
# CNTRL/STORE SUP_spend      0.042     0.000     0.006      0.000      0.013
# COUP/STR & MFG_spend       0.637     0.255     0.347      0.190      0.380
# GM MERCH EXP_spend         0.059     0.048     0.023      0.021      0.061
# DELI/SNACK BAR_spend       0.028     0.000     0.017      0.000      0.000
# Photo/Video_spend          0.023     0.122     0.000      0.054      0.000
# RX_spend                   0.093     0.118     0.177      0.000      0.000
# VIDEO RENTAL_spend         0.000     0.000     0.089      0.000      0.000
# gender                     1.233     1.019     1.150      1.010      1.171
# homeowner_code             1.352     1.396     0.738      1.825      0.951
# total_quantity        233470.422 14539.130  9882.235   3598.602   8857.561
# total_sales_value       4991.345  3730.636  2440.559   1992.234   1987.171
# unique_dep_count          11.610    10.610     8.947      8.563      8.951
# cluster_kmeans             1.562     1.532     1.503      1.854      1.439
#
# cluster_umap_dbscan           10
# household_key           1032.820
# retail_disc               -0.577
# marital_status_code        0.860
# adult_category_size        1.720
# has_kids                   0.480
# avg_age                   43.080
# avg_income            224500.000
# n_kids                     0.660
# n_household                2.380
# Groceries_spend         1012.515
# Delicacies_spend          48.942
# Meat_spend               261.334
# Bakery_spend              30.747
# DRUG GM_spend            161.231
# SALAD BAR_spend            7.014
# MISC SALES TRAN_spend      4.148
# RESTAURANT_spend           0.283
# FLORAL_spend               5.888
# Seafood_spend             12.139
# COSMETICS_spend            7.849
# KIOSK-GAS_spend            0.000
# CHEF SHOPPE_spend          0.395
# GARDEN CENTER_spend        1.679
# MISC. TRANS._spend         0.687
# SPIRITS_spend              3.039
# AUTOMOTIVE_spend           0.096
# TRAVEL & LEISUR_spend      0.718
# CNTRL/STORE SUP_spend      0.000
# COUP/STR & MFG_spend       0.096
# GM MERCH EXP_spend         0.000
# DELI/SNACK BAR_spend       0.000
# Photo/Video_spend          0.000
# RX_spend                   0.000
# VIDEO RENTAL_spend         0.000
# gender                     1.520
# homeowner_code             1.380
# total_quantity           694.320
# total_sales_value       1558.799
# unique_dep_count           7.700
# cluster_kmeans             0.820

# %% [markdown]
# ## 6. Export
#
# <a class='anchor' id='1'></a>
# [Top &#129033;](#0)

# %%
info_numeric.to_csv(f'{path}/cluster_data_num.csv', index=False)

# %% [markdown]
# #### <center>Visualisations for Power BI <center>

# %%
info_numeric.describe()
# Out:
#        household_key  retail_disc  marital_status_code  adult_category_size  \
# count       2500.000     2500.000             2500.000             2500.000
# mean        1250.500       -0.560                0.989                1.447
# std          721.832        0.278                0.852                0.497
# min            1.000       -4.752                0.000                1.000
# 25%          625.750       -0.637                0.000                1.000
# 50%         1250.500       -0.504                1.000                1.000
# 75%         1875.250       -0.413                2.000                2.000
# max         2500.000       -0.036                2.000                2.000
#
#        has_kids  avg_age  avg_income   n_kids  n_household  Groceries_spend  \
# count  2500.000 2500.000    2500.000 2500.000     2500.000         2500.000
# mean      0.338   39.913   78072.000    0.443        1.954         2033.183
# std       0.473   14.452   66852.827    0.706        1.048         2063.025
# min       0.000   21.500   15000.000    0.000        1.000            1.860
# 25%       0.000   29.500   29500.000    0.000        1.000          616.980
# 50%       0.000   39.500   62000.000    0.000        2.000         1377.490
# 75%       1.000   49.500  112000.000    1.000        3.000         2816.665
# max       1.000   65.000  250000.000    3.000        5.000        16223.980
#
#        Delicacies_spend  Meat_spend  Bakery_spend  DRUG GM_spend  \
# count          2500.000    2500.000      2500.000       2500.000
# mean            111.688     411.464        52.115        451.721
# std             172.715     456.970        71.598        600.312
# min               0.000       0.000         0.000          0.000
# 25%              13.088      92.433         8.852         96.268
# 50%              49.230     261.750        27.795        240.665
# 75%             133.697     547.687        69.075        570.535
# max            1935.010    3736.710       916.070       5934.370
#
#        SALAD BAR_spend  MISC SALES TRAN_spend  RESTAURANT_spend  FLORAL_spend  \
# count         2500.000               2500.000          2500.000      2500.000
# mean            13.248                 51.343             0.851        16.973
# std             38.201                332.715             6.845        41.783
# min              0.000                  0.000             0.000         0.000
# 25%              0.000                  0.000             0.000         0.000
# 50%              0.000                  2.130             0.000         0.000
# 75%             10.325                 16.340             0.000        18.260
# max            675.230              11942.400           178.190       938.560
#
#        Seafood_spend  COSMETICS_spend  KIOSK-GAS_spend  CHEF SHOPPE_spend  \
# count       2500.000         2500.000         2500.000           2500.000
# mean          39.632           13.850          232.928              0.981
# std           83.126           33.447          532.531              3.752
# min            0.000            0.000            0.000              0.000
# 25%            0.000            0.000            0.000              0.000
# 50%           12.820            1.060           21.400              0.000
# 75%           41.940           12.197          192.893              0.000
# max         1821.180          566.110         8184.660             80.000
#
#        GARDEN CENTER_spend  MISC. TRANS._spend  SPIRITS_spend  \
# count             2500.000            2500.000       2500.000
# mean                 3.282               4.571          9.275
# std                 23.500              35.974         68.039
# min                  0.000               0.000          0.000
# 25%                  0.000               0.000          0.000
# 50%                  0.000               0.000          0.000
# 75%                  0.000               2.450          0.000
# max               1002.260            1067.880       2827.090
#
#        AUTOMOTIVE_spend  TRAVEL & LEISUR_spend  CNTRL/STORE SUP_spend  \
# count          2500.000               2500.000               2500.000
# mean              0.194                  1.092                  0.021
# std               1.665                  3.618                  0.495
# min               0.000                  0.000                  0.000
# 25%               0.000                  0.000                  0.000
# 50%               0.000                  0.000                  0.000
# 75%               0.000                  0.000                  0.000
# max              36.020                 68.770                 21.400
#
#        COUP/STR & MFG_spend  GM MERCH EXP_spend  DELI/SNACK BAR_spend  \
# count              2500.000            2500.000              2500.000
# mean                  0.440               0.043                 0.015
# std                   2.425               0.514                 0.328
# min                   0.000               0.000                 0.000
# 25%                   0.000               0.000                 0.000
# 50%                   0.000               0.000                 0.000
# 75%                   0.000               0.000                 0.000
# max                  50.450              12.890                13.580
#
#        Photo/Video_spend  RX_spend  VIDEO RENTAL_spend   gender  \
# count           2500.000  2500.000            2500.000 2500.000
# mean               0.033     0.068               0.009    1.135
# std                0.494     1.050               0.280    0.804
# min                0.000     0.000               0.000    0.000
# 25%                0.000     0.000               0.000    0.000
# 50%                0.000     0.000               0.000    1.000
# 75%                0.000     0.000               0.000    2.000
# max               14.970    22.350              11.220    2.000
#
#        homeowner_code  total_quantity  total_sales_value  unique_dep_count  \
# count        2500.000        2500.000           2500.000          2500.000
# mean            1.445      104274.249           3449.055            10.005
# std             1.502      244456.076           3583.873             3.224
# min             0.000           5.000              8.740             1.000
# 25%             0.000         770.000           1038.827             8.000
# 50%             1.000       11084.500           2309.105            10.000
# 75%             2.000       87640.000           4722.680            12.000
# max             4.000     4479917.000          41004.030            19.000
#
#        cluster_kmeans
# count        2500.000
# mean            1.691
# std             1.432
# min             0.000
# 25%             0.000
# 50%             1.000
# 75%             3.000
# max             4.000

# %%
cluster_sales = info_numeric.groupby('cluster_kmeans')['total_sales_value'].sum().reset_index()

# Plot the results
plt.figure(figsize=(8, 6))
plt.bar(cluster_sales['cluster_kmeans'], cluster_sales['total_sales_value'], color='skyblue')
plt.xlabel('Cluster')
plt.ylabel('Total Sales Value')
plt.title('Total Sales Value per Cluster')
plt.xticks(cluster_sales['cluster_kmeans'])
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot histogram for average income
plt.hist(df['avg_income'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Average Income')
plt.ylabel('Frequency')
plt.title('Histogram of Average Income')

# Save the plot as an image
plt.savefig(f'{path}/histogram_avg_income.png')
plt.close()  # Close the plot to free up memory

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data['avg_age'], bins=30, kde=True)
plt.title('Distribution of Average Age')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

avg_age_per_cluster = info_numeric.groupby('cluster_kmeans')['avg_age'].mean().reset_index()

# Rename columns for better clarity
avg_age_per_cluster.columns = ['Cluster', 'Average Age']

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Cluster', y='Average Age', data=avg_age_per_cluster, palette='viridis')

# Customize the plot
plt.title('Average Age per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Age')
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary

# Show the plot
plt.show()
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_3644\4062033630.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='Average Age', data=avg_age_per_cluster, palette='viridis')

# %%
data = info_numeric

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

observations_per_cluster = data['cluster_kmeans'].value_counts().reset_index()

# Rename columns for clarity
observations_per_cluster.columns = ['Cluster', 'Number of Observations']

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Cluster', y='Number of Observations', data=observations_per_cluster, palette='viridis')

# Customize the plot
plt.title('Number of Observations per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Observations')
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary

# Show the plot
plt.show()
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_3644\3141342331.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='Number of Observations', data=observations_per_cluster, palette='viridis')

# %%
observations_per_cluster = data['cluster_kmeans'].value_counts().reset_index()
observations_per_cluster.columns = ['Cluster', 'Number of Observations']

# Create the bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Cluster', y='Number of Observations', data=observations_per_cluster, palette='Set2')

# Add annotations on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center',
                xytext=(0, 5),  # 5 points vertical offset
                textcoords='offset points')

# Customize the plot
plt.title('Number of Observations per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Observations')
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary

# Display the plot
plt.show()
# Out:
# C:\Users\aprataso\AppData\Local\Temp\ipykernel_3644\2440611464.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Cluster', y='Number of Observations', data=observations_per_cluster, palette='Set2')
