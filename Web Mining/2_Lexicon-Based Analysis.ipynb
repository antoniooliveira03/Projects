# %% [markdown]
# # Table of Contents
#
# 1. [Importing Data & Libraries](#1.-Importing-Data-&-Libraries)<br>
#     1.1 [Libraries](#1.1-Libraries) <br>
#     1.2 [Data](#1.2-Importing-Data) <br>
# 2. [Lexicon Based Sentiment Analysis](#2.-Lexicon-Based-Sentiment-Analysis) <br>
#     2.1 [Vader](#2.1-Vader)<br>
#         2.1.1 [Visualisations](#2.1.1-Visualisations)<br>
#     2.2 [TextBlob](#2.2-TextBlob-Sentiment-Analyzer)<br>
#         2.2.1 [Visualisations](#2.2.1-Visualisations)<br>
#     2.3 [AFINN](#2.3-AFINN)<br>
#         2.3.1 [Visualisations](#2.3.1-Visualisations)<br>
#         2.3.2 [Normalised AFINN](#2.3.2-Normalised-AFINN)<br>
# 3. [Model Comparison](#3.-Model-Comparison)<br>
# 4. [Further Exploration](#4.-Further-Exploration)

# %% [markdown]
# In this notebook we will continue to explore our data by using Lexicon-Based Sentiment Analysers.

# %% [markdown]
# ** **

# %% [markdown]
# ## 1. Importing Data & Libraries

# %% [markdown]
# ### 1.1 Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# AFINN
from afinn import Afinn

# Scaler
from sklearn.preprocessing import MinMaxScaler

# External files
import preprocessing
import lexicon_based



pd.set_option('display.max_columns', None)

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# **Veryfying if the functions of the external py files were imported**

# %%
functions = [func for func in dir(lexicon_based) if callable(getattr(lexicon_based, func))]

# Print the list of functions
print("Functions in the external module:")
for func in functions:
    print(func)
# Out:
# Functions in the external module:
# SentimentIntensityAnalyzer
# TextBlob
# plot_sentiment_histograms
# textblob_sa
# textblob_subjectivity
# vader_algorithm

# %% [markdown]
# ### 1.2 Data

# %%
dataset = pd.read_csv('/Users/antoniooliveira/MannheimWMProject/processed_data_v2.csv')

# %%
dataset.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended  Sentiment  Year  review_length  \
# 0               9         yes          2  2024            467
# 1               3          no          0  2024            249
# 2              10         yes          2  2024            196
# 3              10         yes          2  2024            991
# 4              10         yes          2  2024            310
#
#                                            Reviews_1
# 0  Flight amazing. The crew onboard flight welcom...
# 1  Booking emergency exit seat still meant huge d...
# 2  Excellent performance fronts. I would definite...
# 3  Pretty comfortable flight considering I flying...
# 4  The service consistently good start finish. Th...

# %% [markdown]
# ## 2. Lexicon Based Sentiment Analysis

# %% [markdown]
# **Sorting the observations by sentiment, and saving them in sorted_sentiment**

# %%
sorted_sentiment = sorted(dataset['Sentiment'].unique())

# %% [markdown]
# ### 2.1 Vader

# %% [markdown]
# **Applying Vader on the preprocessed column** *Reviews_1*

# %%
dataset["vader_polarity_compound"] = dataset["Reviews_1"].apply(lambda review : lexicon_based.vader_algorithm(str(review)))

dataset["vader_polarity_scores"] = dataset["Reviews_1"].apply(lambda review : lexicon_based.vader_algorithm(str(review), compound = False))

# %% [markdown]
# Grouping observations by their polarity

# %%
dataset.groupby('Sentiment')['vader_polarity_compound'].describe()
# Out:
#             count      mean       std     min       25%      50%     75%  \
# Sentiment
# 0          3022.0 -0.252487  0.671934 -0.9928 -0.847675 -0.52785  0.4019
# 1          1672.0  0.399248  0.646049 -0.9931 -0.120525  0.73305  0.9300
# 2          3405.0  0.875072  0.256647 -0.9308  0.900100  0.95690  0.9779
#
#               max
# Sentiment
# 0          0.9953
# 1          0.9964
# 2          0.9993

# %% [markdown]
# #### 2.1.1 Visualisations

# %% [markdown]
# **Polarity Histogram per Sentiment**

# %%
lexicon_based.plot_sentiment_histograms(dataset, sorted_sentiment, 'vader_polarity_compound')

# %% [markdown]
# **Polarity boxplots per Sentiment**

# %%
combined_data = pd.concat([dataset[dataset['Sentiment'] == sentiment] for sentiment in sorted_sentiment])

sns.boxplot(data=combined_data, x='Sentiment', y='vader_polarity_compound', palette ='Blues')
plt.title('Sentiment Analysis')
plt.show()

# %% [markdown]
# **Total Count histogram**

# %%
sns.displot(dataset["vader_polarity_compound"], kde=True, bins=5)
plt.show()

# %% [markdown]
# ### 2.2 TextBlob Sentiment Analyzer

# %% [markdown]
# **Applying TextBlob to compute the polarity and subjectivity** *Reviews_1*

# %%
dataset["textblob_polarity_compound"] = dataset["Reviews_1"].apply(lambda review : lexicon_based.textblob_sa(str(review)))

# %%
dataset["textblob_subjectivity"] = dataset["Reviews_1"].apply(lexicon_based.textblob_subjectivity)

# %% [markdown]
# Grouping observations by their polarity

# %%
dataset.groupby('Sentiment')['textblob_polarity_compound'].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Sentiment
# 0          3022.0 -0.024396  0.181879 -1.000000 -0.116667 -0.009902  0.078085
# 1          1672.0  0.112089  0.170221 -1.000000  0.014012  0.114794  0.212289
# 2          3405.0  0.321930  0.163338 -0.666667  0.219331  0.315278  0.417500
#
#            max
# Sentiment
# 0          1.0
# 1          0.8
# 2          1.0

# %% [markdown]
# #### 2.2.1 Visualisations

# %% [markdown]
# **Polarity Histogram per Sentiment**

# %%
lexicon_based.plot_sentiment_histograms(dataset, sorted_sentiment, 'textblob_polarity_compound')

# %% [markdown]
# **Polarity boxplots per Sentiment**

# %%
combined_data = pd.concat([dataset[dataset['Sentiment'] == sentiment] for sentiment in sorted_sentiment])

sns.boxplot(data=combined_data, x='Sentiment', y='textblob_polarity_compound',  palette ='Blues')
plt.title('Sentiment Analysis')
plt.show()

# %% [markdown]
# **Total Count histogram**

# %%
sns.displot(dataset["textblob_polarity_compound"], kde=True, bins=5)
plt.show()

# %% [markdown]
# ### 2.3 AFINN

# %% [markdown]
# **Applying AFINN on the preprocessed column** *Reviews_1*

# %%
afinn = Afinn()

dataset['Afinn_polarity_compound'] = dataset['Reviews_1'].apply(lambda x: 
                                              afinn.score(x))

# %% [markdown]
# Grouping observations by their polarity

# %%
dataset.groupby('Sentiment')['Afinn_polarity_compound'].describe()
# Out:
#             count       mean       std   min  25%   50%   75%    max
# Sentiment
# 0          3022.0  -4.011582  7.902011 -46.0 -8.0  -4.0   0.0   51.0
# 1          1672.0   4.867823  9.389624 -36.0 -1.0   4.0  10.0   45.0
# 2          3405.0  14.209985  9.557496 -16.0  8.0  13.0  19.0  108.0

# %% [markdown]
# #### 2.3.1 Visualisations

# %% [markdown]
# **Polarity Histogram per Sentiment**

# %%
lexicon_based.plot_sentiment_histograms(dataset, sorted_sentiment, 'Afinn_polarity_compound')

# %% [markdown]
# **Polarity boxplots per Sentiment**

# %%
combined_data = pd.concat([dataset[dataset['Sentiment'] == sentiment] for sentiment in sorted_sentiment])

sns.boxplot(data=combined_data, x='Sentiment', y='Afinn_polarity_compound',  palette ='Blues')
plt.title('Sentiment Analysis')
plt.show()

# %% [markdown]
# **Total Count histogram**

# %%
sns.displot(dataset["Afinn_polarity_compound"], kde=True, bins=5)
plt.show()

# %% [markdown]
# #### 2.3.2 Normalised AFINN

# %% [markdown]
# Since the AFINN algorithm has a very large range of values, we decided to scale it from -1 to 1 for an easier comparison with the rest of the algorithms

# %%
scaler = MinMaxScaler(feature_range = (-1,1))

dataset["Afinn_normalized_polarity"] = scaler.fit_transform(dataset["Afinn_polarity_compound"].to_numpy().reshape(-1, 1))

# %% [markdown]
# Grouping observations by their polarity

# %%
dataset.groupby('Sentiment')['Afinn_normalized_polarity'].describe()
# Out:
#             count      mean       std      min       25%       50%       75%  \
# Sentiment
# 0          3022.0 -0.454696  0.102624 -1.00000 -0.506494 -0.454545 -0.402597
# 1          1672.0 -0.339379  0.121943 -0.87013 -0.415584 -0.350649 -0.272727
# 2          3405.0 -0.218052  0.124123 -0.61039 -0.298701 -0.233766 -0.155844
#
#                 max
# Sentiment
# 0          0.259740
# 1          0.181818
# 2          1.000000

# %% [markdown]
# #### 2.3.2 Visualisations

# %% [markdown]
# **Polarity Histogram per Sentiment**

# %%
lexicon_based.plot_sentiment_histograms(dataset, sorted_sentiment, 'Afinn_normalized_polarity')

# %% [markdown]
# **Polarity boxplots per Sentiment**

# %%
combined_data = pd.concat([dataset[dataset['Sentiment'] == sentiment] for sentiment in sorted_sentiment])

sns.boxplot(data=combined_data, x='Sentiment', y='Afinn_normalized_polarity', palette ='Blues')
plt.title('Sentiment Analysis')
plt.show()

# %% [markdown]
# **Total Count histogram**

# %%
sns.displot(dataset["Afinn_normalized_polarity"], kde=True, bins=5)
plt.show()

# %% [markdown]
# ### 3. Model Comparison

# %% [markdown]
# **Palette**

# %%
palette = sns.color_palette("Blues")

# %% [markdown]
# Listing the columns to be compared

# %%
compare = ['vader_polarity_compound', 'textblob_polarity_compound', 
           'Afinn_normalized_polarity']

# %% [markdown]
# **Mean of each algorithm per sentiment**

# %%
means_by_sentiment = dataset.groupby('Sentiment')[compare].mean()

# Plot the means
ax = means_by_sentiment.plot(kind='bar', figsize=(10, 6), color=palette)
plt.title('Mean Polarity Compound per Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Mean Polarity Compound')

# Change the legend location to the upper right
ax.legend(title='Polarity Compound', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# **Mean Polarity change accross the years**

# %%
grouped_data = combined_data.groupby('Year')

# Calculate mean polarity for each year
mean_polarity = grouped_data[['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']].mean()

# Plot the data
mean_polarity.plot(kind='line', marker='o', color=palette)
plt.title('Mean Polarity Across Years')
plt.xlabel('Year')
plt.ylabel('Mean Polarity')
plt.xticks(mean_polarity.index)
plt.legend()
plt.show()

# %% [markdown]
# **Polarity change across the years in the three sentiments**

# %%
grouped_data = combined_data.groupby(['Year', 'Sentiment'])

# Calculate polarity statistics for each group
polarity_stats = grouped_data[['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']].describe()

# Plot the data for each sentiment analysis method
sns.set(style="whitegrid")

# Iterate over each sentiment analysis method
for method in ['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=combined_data, x='Sentiment', y=method, hue='Year', palette='Blues')
    plt.title(f'{method} Polarity Variation Across Sentiments and Years')
    plt.xlabel('Sentiment Category')
    plt.ylabel('Polarity')
    plt.legend(title='Year', loc='upper right')
    plt.show()

# %% [markdown]
# **Polarity variation across the years for each Class**

# %%
grouped_data = combined_data.groupby(['Class', 'Year'])
mean_polarity_by_class_and_year = grouped_data[['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']].mean().reset_index()

# Define a color palette
palette = sns.color_palette("Blues", len(mean_polarity_by_class_and_year['Class'].unique()))

# Plot the data for each sentiment analysis method
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True)

for i, method in enumerate(['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']):
    ax = axes[i]
    for j, class_ in enumerate(mean_polarity_by_class_and_year['Class'].unique()):
        class_data = mean_polarity_by_class_and_year[mean_polarity_by_class_and_year['Class'] == class_]
        ax.plot(class_data['Year'], class_data[method], marker='o', label=class_, color=palette[j])
    ax.set_title(method)
    ax.set_xlabel('Year')
    ax.set_ylabel('Mean Polarity')
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Polarity variation accross the years for each Type of Traveller**

# %%
grouped_data = combined_data.groupby(['Type of Traveller', 'Year'])
mean_polarity_by_traveler_and_year = grouped_data[['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']].mean().reset_index()

# Define a color palette
palette = sns.color_palette("Blues", len(mean_polarity_by_traveler_and_year['Type of Traveller'].unique()))

# Plot the data for each sentiment analysis method
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), sharey=True)  # Create subplots for each sentiment analysis method

for i, method in enumerate(['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']):
    ax = axes[i]
    for j, traveler_type in enumerate(mean_polarity_by_traveler_and_year['Type of Traveller'].unique()):
        traveler_data = mean_polarity_by_traveler_and_year[mean_polarity_by_traveler_and_year['Type of Traveller'] == traveler_type]
        ax.plot(traveler_data['Year'], traveler_data[method], marker='o', label=traveler_type, color=palette[j])
    ax.set_title(method)
    ax.set_xlabel('Year')
    ax.set_ylabel('Mean Polarity')
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Polarity variation across Inflight Experience categories**

# %%
# Define the categories and methods
categories = ['Seat Comfort', 'Staff Service', 'Food & Beverages', 'Inflight Entertainment', 'Value For Money']
methods = ['vader_polarity_compound', 'textblob_polarity_compound', 'Afinn_normalized_polarity']

num_categories = len(categories)
num_methods = len(methods)
fig, axes = plt.subplots(num_categories, num_methods, figsize=(25, 20), sharey=True)
fig.suptitle('Mean Polarity by Category and Method \n\n', fontsize=16)

# Define a color palette
palette = sns.color_palette("Blues_d", num_categories * num_methods)

# Plotting
for i, category in enumerate(categories):
    for j, method in enumerate(methods):
        mean_polarity = dataset.groupby(category)[method].mean().reset_index()
        sns.barplot(x=category, y=method, data=mean_polarity, ax=axes[i, j], palette=[palette[i+j]])
        axes[i, j].set_title(f'{method.replace("_", " ").title()} for {category.replace("_", " ").title()}')
        axes[i, j].set_xlabel(category.replace("_", " ").title())
        axes[i, j].set_ylabel('Mean Polarity')
        axes[i, j].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Further Exploration

# %% [markdown]
# **High sentiment with low Polarity**

# %%
dataset[(dataset['Sentiment'] == 2) & (dataset['vader_polarity_compound'] < 0)]
# Out:
#                                       Title              Name Review Date  \
# 64           experience was second to none        Ricky Sharp  2023-09-15
# 278      wanted to thank Singapore Airlines    Frances Jojart  2020-08-15
# 401   deterioration in the level of service          C Dalton  2019-10-03
# 412                Everything went smoothly        H Marukesh  2019-09-22
# 488              Everything was as expected  Grahame Williams  2019-04-30
# ...                                     ...               ...         ...
# 7625     professional and attentive service       B Crockford  2016-04-05
# 7709        pointed to where to get luggage         G Carleno  2019-12-08
# 7777               cabin crew was excellent        Doug Dumpa  2018-07-27
# 7919                  above average legroom         P Gregory  2023-09-25
# 8058              The legroom is remarkable    Brian Lamprell  2017-06-08
#
#                      Airline Verified  \
# 64        Singapore Airlines     True
# 278       Singapore Airlines     True
# 401       Singapore Airlines     True
# 412       Singapore Airlines     True
# 488       Singapore Airlines     True
# ...                      ...      ...
# 7625  Cathay Pacific Airways     True
# 7709                 EVA Air     True
# 7777                 EVA Air     True
# 7919              Korean Air     True
# 8058              Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 64      I have just flown SQ256 from Brisbane to Sin...          Business
# 278    We have yet to fly with Singapore Airlines an...    Couple Leisure
# 401     Singapore to Perth. Was disappointed with th...    Family Leisure
# 412     Melbourne to Mumbai via Singapore. Everythin...    Family Leisure
# 488     Singapore to Melbourne. Everything was as ex...      Solo Leisure
# ...                                                 ...               ...
# 7625    Late departure from SIN on the 8pm flight me...      Solo Leisure
# 7709    Tokyo to San Francisco via Taipei. EVA needs...      Solo Leisure
# 7777    San Francisco to Manila via Taipei. The chec...          Business
# 7919   Very satisfied with the overall experience. A...    Couple Leisure
# 8058    Toronto to Sydney via Seoul Incheon. This wa...    Couple Leisure
#
#          Month Flown                                Route            Class  \
# 64        April 2023                Brisbane to Singapore   Business Class
# 278      August 2020       Sao Paulo to Dublin via Munich   Business Class
# 401        July 2019                 Jakarta to Singapore   Business Class
# 412   September 2019         Seoul to Kochi via Singapore    Economy Class
# 488       April 2019                  Singapore to Manila  Premium Economy
# ...              ...                                  ...              ...
# 7625      March 2016                           SIN to HKG   Business Class
# 7709   November 2019    Tokyo to San Francisco via Taipei  Premium Economy
# 7777       July 2018   San Francisco to Manila via Taipei    Economy Class
# 7919  September 2023     Seoul Incheon to London Heathrow    Economy Class
# 8058       June 2017  Toronto to Sydney via Seoul Incheon    Economy Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 64               1              5                 5                       5
# 278              5              4                 3                       4
# 401              5              5                 1                       1
# 412              3              3                 3                       4
# 488              5              4                 5                       1
# ...            ...            ...               ...                     ...
# 7625             2              3                 1                       5
# 7709             4              5                 4                       3
# 7777             4              4                 5                       4
# 7919             4              4                 4                       1
# 8058             5              5                 5                       4
#
#       Value For Money  Overall Rating Recommended  Sentiment  Year  \
# 64                  5              10         yes          2  2023
# 278                 5              10         yes          2  2020
# 401                 4               8         yes          2  2019
# 412                 4              10         yes          2  2019
# 488                 4               8         yes          2  2019
# ...               ...             ...         ...        ...   ...
# 7625                4               9         yes          2  2016
# 7709                5               8         yes          2  2019
# 7777                5               8         yes          2  2018
# 7919                4               8         yes          2  2023
# 8058                5               8         yes          2  2017
#
#       review_length                                          Reviews_1  \
# 64              134  I flown SQ256 Brisbane Singapore experience se...
# 278             269  We yet fly Singapore Airlines n't look like fo...
# 401             596  Singapore Perth. Was disappointed level servic...
# 412             656  Melbourne Mumbai via Singapore. Everything che...
# 488             214  Singapore Melbourne. Everything expected terms...
# ...             ...                                                ...
# 7625            327  Late departure SIN 8pm flight meant late arriv...
# 7709            884  Tokyo San Francisco via Taipei. EVA needs unde...
# 7777            647  San Francisco Manila via Taipei. The check-in ...
# 7919            525  Very satisfied overall experience. Airfares in...
# 8058           1650  Toronto Sydney via Seoul Incheon. This return ...
#
#       vader_polarity_compound  \
# 64                    -0.2778
# 278                   -0.1556
# 401                   -0.6369
# 412                   -0.2960
# 488                   -0.3818
# ...                       ...
# 7625                  -0.9251
# 7709                  -0.5709
# 7777                  -0.3933
# 7919                  -0.6314
# 8058                  -0.4404
#
#                                   vader_polarity_scores  \
# 64    {'neg': 0.197, 'neu': 0.674, 'pos': 0.129, 'co...
# 278   {'neg': 0.149, 'neu': 0.761, 'pos': 0.091, 'co...
# 401   {'neg': 0.155, 'neu': 0.754, 'pos': 0.091, 'co...
# 412   {'neg': 0.033, 'neu': 0.967, 'pos': 0.0, 'comp...
# 488   {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'comp...
# ...                                                 ...
# 7625  {'neg': 0.373, 'neu': 0.572, 'pos': 0.055, 'co...
# 7709  {'neg': 0.153, 'neu': 0.699, 'pos': 0.147, 'co...
# 7777  {'neg': 0.095, 'neu': 0.85, 'pos': 0.055, 'com...
# 7919  {'neg': 0.169, 'neu': 0.68, 'pos': 0.151, 'com...
# 8058  {'neg': 0.091, 'neu': 0.845, 'pos': 0.064, 'co...
#
#       textblob_polarity_compound  textblob_subjectivity  \
# 64                      0.250000               0.437500
# 278                     0.266667               0.383333
# 401                    -0.078205               0.419872
# 412                     0.063889               0.294444
# 488                    -0.200000               0.500000
# ...                          ...                    ...
# 7625                   -0.085714               0.416667
# 7709                    0.097269               0.444188
# 7777                    0.226667               0.500000
# 7919                    0.025000               0.541667
# 8058                    0.094180               0.519048
#
#       Afinn_polarity_compound  Afinn_normalized_polarity
# 64                        5.0                  -0.337662
# 278                       3.0                  -0.363636
# 401                      -1.0                  -0.415584
# 412                      -3.0                  -0.441558
# 488                       0.0                  -0.402597
# ...                       ...                        ...
# 7625                     -9.0                  -0.519481
# 7709                      1.0                  -0.389610
# 7777                     -1.0                  -0.415584
# 7919                      5.0                  -0.337662
# 8058                     -3.0                  -0.441558
#
# [79 rows x 27 columns]

# %%
dataset['Reviews'].iloc[64]
# Out:
# '\xa0\xa0I have just flown SQ256 from Brisbane to Singapore and the experience was second to none with outstanding cabin crew. Well done SQ, '

# %% [markdown]
# **AFINN Incoherencies**

# %%
dataset[(dataset['Afinn_polarity_compound'] > 0) & (dataset['Afinn_normalized_polarity'] <= 0)]
# Out:
#                                      Title              Name Review Date  \
# 0                       Flight was amazing  Alison Soetantyo  2024-03-01
# 2             Food was plentiful and tasty             S Han  2024-02-20
# 3             “how much food was available          D Laynes  2024-02-19
# 4          “service was consistently good”         A Othman   2024-02-19
# 6                    Very ordinary service          S Holger  2024-02-19
# ...                                    ...               ...         ...
# 8092  I was satisfied with the performance             F Lee  2016-07-09
# 8094                  an uneventful flight         N Vickers  2016-06-20
# 8095           Korean Air always impresses      Kim Holloway  2016-06-12
# 8097       appreciated the service onboard           E Petan  2016-04-21
# 8098              genuinely friendly staff           D Lanor  2016-04-12
#
#                  Airline Verified  \
# 0     Singapore Airlines     True
# 2     Singapore Airlines     True
# 3     Singapore Airlines     True
# 4     Singapore Airlines     True
# 6     Singapore Airlines     True
# ...                  ...      ...
# 8092          Korean Air     True
# 8094          Korean Air     True
# 8095          Korean Air    False
# 8097          Korean Air    False
# 8098          Korean Air    False
#
#                                                 Reviews Type of Traveller  \
# 0       Flight was amazing. The crew onboard this fl...      Solo Leisure
# 2       Excellent performance on all fronts. I would...    Family Leisure
# 3      Pretty comfortable flight considering I was f...      Solo Leisure
# 4      The service was consistently good from start ...    Family Leisure
# 6       Boarding process went smoothly, and plane le...      Solo Leisure
# ...                                                 ...               ...
# 8092   Flown from Seattle to Incheon and then Incheo...      Solo Leisure
# 8094    KE124, Brisbane to Incheon (A330) and KE867,...          Business
# 8095    Our recent flight was our fourth trip to the...    Couple Leisure
# 8097    Seoul to Paris with Korean Air. I am traveli...          Business
# 8098    The 13 hour flight in Business class from Se...          Business
#
#         Month Flown                         Route           Class  \
# 0     December 2023          Jakarta to Singapore  Business Class
# 2     February 2024        Siem Reap to Singapore   Economy Class
# 3     February 2024  Singapore to London Heathrow   Economy Class
# 4     February 2024       Singapore to Phnom Penh   Economy Class
# 6     February 2024        Singapore to Frankfurt   Economy Class
# ...             ...                           ...             ...
# 8092      July 2016            SEA to SIN via ICN   Economy Class
# 8094      June 2016            BNE to ULN via ICN   Economy Class
# 8095      June 2016            SYD to LHR via ICN   Economy Class
# 8097     April 2016                    ICN to CDG  Business Class
# 8098     April 2016                    ICN to YYZ  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# 6                1              3                 1                       2
# ...            ...            ...               ...                     ...
# 8092             3              4                 5                       4
# 8094             5              4                 5                       3
# 8095             3              5                 5                       4
# 8097             5              1                 3                       4
# 8098             3              5                 3                       3
#
#       Value For Money  Overall Rating Recommended  Sentiment  Year  \
# 0                   4               9         yes          2  2024
# 2                   5              10         yes          2  2024
# 3                   5              10         yes          2  2024
# 4                   5              10         yes          2  2024
# 6                   2               5          no          1  2024
# ...               ...             ...         ...        ...   ...
# 8092                3               7         yes          1  2016
# 8094                4               7         yes          1  2016
# 8095                5              10         yes          2  2016
# 8097                5              10         yes          2  2016
# 8098                5              10         yes          2  2016
#
#       review_length                                          Reviews_1  \
# 0               467  Flight amazing. The crew onboard flight welcom...
# 2               196  Excellent performance fronts. I would definite...
# 3               991  Pretty comfortable flight considering I flying...
# 4               310  The service consistently good start finish. Th...
# 6               866  Boarding process went smoothly, plane left tim...
# ...             ...                                                ...
# 8092            740  Flown Seattle Incheon Incheon Singapore Korean...
# 8094            751  KE124, Brisbane Incheon( A330) KE867, Incheon ...
# 8095           1127  Our recent flight fourth trip UK 6 years Sydne...
# 8097           1298  Seoul Paris Korean Air. I traveling triathlon ...
# 8098            279  The 13 hour flight Business class Seoul Toront...
#
#       vader_polarity_compound  \
# 0                      0.9633
# 2                      0.7506
# 3                      0.9784
# 4                      0.9542
# 6                      0.6969
# ...                       ...
# 8092                   0.9451
# 8094                   0.2500
# 8095                   0.9921
# 8097                   0.9902
# 8098                   0.9231
#
#                                   vader_polarity_scores  \
# 0     {'neg': 0.0, 'neu': 0.692, 'pos': 0.308, 'comp...
# 2     {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'comp...
# 3     {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 4     {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...
# 6     {'neg': 0.013, 'neu': 0.911, 'pos': 0.076, 'co...
# ...                                                 ...
# 8092  {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'comp...
# 8094  {'neg': 0.025, 'neu': 0.938, 'pos': 0.038, 'co...
# 8095  {'neg': 0.015, 'neu': 0.664, 'pos': 0.321, 'co...
# 8097  {'neg': 0.018, 'neu': 0.705, 'pos': 0.278, 'co...
# 8098  {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'comp...
#
#       textblob_polarity_compound  textblob_subjectivity  \
# 0                       0.385185               0.577778
# 2                       0.500000               0.750000
# 3                       0.300219               0.563698
# 4                       0.400000               0.542857
# 6                       0.120833               0.422500
# ...                          ...                    ...
# 8092                    0.245357               0.419286
# 8094                    0.166667               0.425000
# 8095                    0.309625               0.497899
# 8097                    0.314441               0.569048
# 8098                    0.255000               0.380000
#
#       Afinn_polarity_compound  Afinn_normalized_polarity
# 0                        20.0                  -0.142857
# 2                         3.0                  -0.363636
# 3                        15.0                  -0.207792
# 4                        14.0                  -0.220779
# 6                         4.0                  -0.350649
# ...                       ...                        ...
# 8092                      4.0                  -0.350649
# 8094                      2.0                  -0.376623
# 8095                     24.0                  -0.090909
# 8097                     21.0                  -0.129870
# 8098                     10.0                  -0.272727
#
# [4895 rows x 27 columns]

# %%
dataset['Afinn_polarity_compound'].max()
# Out:
# 108.0
